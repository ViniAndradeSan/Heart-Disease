# %% [markdown]
# # Doença Cardíaca
#
# <table>
#   <td>
#     <a href="https://colab.research.google.com/drive/1Ta7d-4apuKxgIWplJLrpIplThcDSQROY" target="_parent"><img src="https://google.com" alt="Open In Colab"/></a>
#   </td>
# </table>
