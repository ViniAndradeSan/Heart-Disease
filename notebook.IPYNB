# %% [markdown]
# # Doença Cardíaca
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://google.com)

# %%
# Cole o seu código Python aqui depois
print('Código conectado!')
